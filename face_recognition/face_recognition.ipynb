# %%
import face_recognition

# %%
picture_of_me = face_recognition.load_image_file("/data/image1.jpeg")

# %%
my_face_encoding = face_recognition.face_encodings(picture_of_me)[0]

# %%
unknown_picture = face_recognition.load_image_file("/data/vpic1.jpg")

# %%
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]

# %%
my_face_encoding
# Out:
# array([-0.11056037,  0.12505975,  0.00314686, -0.03868851, -0.02235444,
#        -0.07612935,  0.00616472, -0.06990992,  0.21766199, -0.07752866,
#         0.15332514,  0.05217598, -0.17973176,  0.00131213, -0.01098127,
#         0.11246802, -0.11941243, -0.07640249, -0.1639778 , -0.0400459 ,
#         0.11398381,  0.07532748,  0.08694641, -0.02120777, -0.12761892,
#        -0.30810136, -0.13004175, -0.11795615,  0.0116358 , -0.07505684,
#         0.10614759, -0.04056618, -0.1645312 , -0.09671683,  0.01286393,
#         0.02183766, -0.08188374,  0.01222006,  0.21500358,  0.11116196,
#        -0.1873927 ,  0.10606892, -0.00432678,  0.32602173,  0.15160272,
#         0.14758421, -0.01328355, -0.07781158,  0.05294192, -0.26244658,
#         0.12291646,  0.08298275,  0.10659189,  0.03893498,  0.17429963,
#        -0.0729108 ,  0.10186184,  0.0446411 , -0.28090566,  0.0520633 ,
#         0.1195165 , -0.05422448, -0.02401748,  0.01168869,  0.23117729,
# ...

# %%
unknown_face_encoding
# Out:
# array([-0.05216954,  0.0643371 ,  0.02085149, -0.04324039,  0.02420916,
#        -0.06754785, -0.00685233, -0.04899629,  0.22696306, -0.15825133,
#         0.15820952,  0.00538488, -0.20127243, -0.00835419,  0.03651932,
#         0.14614046, -0.16723573, -0.10578281, -0.17925765, -0.06853089,
#         0.04937529, -0.0100129 ,  0.0127955 ,  0.01898207, -0.13224012,
#        -0.2983633 , -0.0587896 , -0.10870069,  0.03479915,  0.01850167,
#         0.02584642, -0.00918126, -0.16813268, -0.11398187,  0.02725648,
#         0.01247979, -0.08518317,  0.03402548,  0.25688896,  0.04881644,
#        -0.18551055,  0.06349681, -0.03684571,  0.32103354,  0.17646958,
#         0.11692128,  0.00953224, -0.09056848,  0.12255875, -0.33482808,
#         0.08549608,  0.14319208,  0.10746113,  0.08289576,  0.13203245,
#        -0.1060333 ,  0.09560611,  0.05316997, -0.24158488,  0.09482523,
#         0.10999323, -0.07899787, -0.01457456, -0.03060796,  0.24585189,
# ...

# %%
results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)

# %%
if results[0] == True:
    print("It's a picture of me!")
else:
    print("It's not a picture of me!")
# Out:
# It's a picture of me!

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(picture_of_me)

# %%
plt.imshow(unknown_picture)

# %%
unknown_picture = face_recognition.load_image_file("/data/AB1.jpg")
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]
plt.imshow(unknown_picture)

# %%
results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)
if results[0] == True:
    print("It's a picture of me!")
else:
    print("It's not a picture of me!")
# Out:
# It's not a picture of me!

# %%
unknown_picture = face_recognition.load_image_file("/data/vpic4.jpg")
unknown_face_encoding = face_recognition.face_encodings(unknown_picture)[0]
plt.imshow(unknown_picture)

# %%
results = face_recognition.compare_faces([my_face_encoding], unknown_face_encoding)
if results[0] == True:
    print("It's a picture of me!")
else:
    print("It's not a picture of me!")
# Out:
# It's a picture of me!
