# %%
# Python API for IBM Cloud
# https://cloud.ibm.com/docs/services/cloud-object-storage/libraries?topic=cloud-object-storage-python
import ibm_boto3
from ibm_botocore.client import Config, ClientError

# Constants for IBM COS values
COS_ENDPOINT = "https://s3.us-east.cloud-object-storage.appdomain.cloud" # Current list avaiable at https://control.cloud-object-storage.cloud.ibm.com/v2/endpoints
COS_API_KEY_ID = "FkhRf4C1KLzuGcbctz16L33TefTcCzpGrBRoLiihMRtJ" # eg "W00YiRnLW4a3fTjMB-odB-2ySfTrFBIQQWanc--P3byk"
COS_AUTH_ENDPOINT = "https://iam.cloud.ibm.com/identity/token"
COS_RESOURCE_CRN = "crn:v1:bluemix:public:cloud-object-storage:global:a/17820f0b43654f6293224ad886b08c6d:df6186d9-51fe-4acf-9516-b23e351782ad::" # eg "crn:v1:bluemix:public:cloud-object-storage:global:a/3bf0d9003abfb5d29761c3e97696b71c:d6f04d83-6c4f-4a62-a165-696756d63903::"

# Create resource
cos = ibm_boto3.resource("s3",
    ibm_api_key_id=COS_API_KEY_ID,
    ibm_service_instance_id=COS_RESOURCE_CRN,
    ibm_auth_endpoint=COS_AUTH_ENDPOINT,
    config=Config(signature_version="oauth"),
    endpoint_url=COS_ENDPOINT
)

# %%
# List Bucket Names
def get_buckets():
    print("Retrieving list of buckets")
    try:
        buckets = cos.buckets.all()
        for bucket in buckets:
            print("Bucket Name: {0}".format(bucket.name))
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))
    except Exception as e:
        print("Unable to retrieve list buckets: {0}".format(e))

# %%
get_buckets()
# Out:
# Retrieving list of buckets
# Bucket Name: cloud-object-storage-w251-hw3-faces
# Bucket Name: cloud-object-storage-w251-ring-video

# %%
# Test file upload information
bucket_name = "cloud-object-storage-w251-ring-video"
upload_filename = "/Users/katayounborojerdi/Desktop/IMG_3521.jpg"
object_name = "test_upload.jpg"

# %%
# File Upload

COS_SERVICE_CRN = "crn:v1:bluemix:public:cloud-object-storage:global:a/17820f0b43654f6293224ad886b08c6d:df6186d9-51fe-4acf-9516-b23e351782ad:bucket:cloud-object-storage-w251-ring-video"

def upload_large_file(bucket_name, item_name, file_path):
    print("Starting large file upload for {0} to bucket: {1}".format(item_name, bucket_name))

    # set the chunk size to 5 MB
    part_size = 1024 * 1024 * 5

    # set threadhold to 5 MB
    file_threshold = 1024 * 1024 * 5

    # Create client connection
    cos_cli = ibm_boto3.client("s3",
        ibm_api_key_id=COS_API_KEY_ID,
        ibm_service_instance_id=COS_SERVICE_CRN,
        ibm_auth_endpoint=COS_AUTH_ENDPOINT,
        config=Config(signature_version="oauth"),
        endpoint_url=COS_ENDPOINT
    )

    # set the transfer threshold and chunk size in config settings
    transfer_config = ibm_boto3.s3.transfer.TransferConfig(
        multipart_threshold=file_threshold,
        multipart_chunksize=part_size
    )

    # create transfer manager
    transfer_mgr = ibm_boto3.s3.transfer.TransferManager(cos_cli, config=transfer_config)

    try:
        # initiate file upload
        future = transfer_mgr.upload(file_path, bucket_name, item_name)

        # wait for upload to complete
        future.result()

        print ("Large file upload complete!")
    except Exception as e:
        print("Unable to complete large file upload: {0}".format(e))
    finally:
        transfer_mgr.shutdown()

# %%
upload_large_file(bucket_name, object_name, upload_filename)
# Out:
# Starting large file upload for test_upload.jpg to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!

# %%
def get_bucket_contents_v2(bucket_name, max_keys):
    print("Retrieving bucket contents from: {0}".format(bucket_name))
    try:
        # create client object
        cos_cli = ibm_boto3.client("s3",
            ibm_api_key_id=COS_API_KEY_ID,
            ibm_service_instance_id=COS_SERVICE_CRN,
            ibm_auth_endpoint=COS_AUTH_ENDPOINT,
            config=Config(signature_version="oauth"),
            endpoint_url=COS_ENDPOINT)

        more_results = True
        next_token = ""

        while (more_results):
            response = cos_cli.list_objects_v2(Bucket=bucket_name, MaxKeys=max_keys, ContinuationToken=next_token)
            files = response["Contents"]
            for file in files:
                print("Item: {0} ({1} bytes).".format(file["Key"], file["Size"]))

            if (response["IsTruncated"]):
                next_token = response["NextContinuationToken"]
                print("...More results in next batch!\n")
            else:
                more_results = False
                next_token = ""

    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))
    except Exception as e:
        print("Unable to retrieve bucket contents: {0}".format(e))

# %%
get_bucket_contents_v2(bucket_name, 100)
# Out:
# Retrieving bucket contents from: cloud-object-storage-w251-ring-video
# Item: 2020-02-28_08:35.mp4 (26176721 bytes).
# Item: 2020-02-28_11:47.mp4 (28394994 bytes).
# Item: 2020-02-28_11:48.mp4 (26247747 bytes).
# Item: 2020-02-28_12:22.mp4 (26281752 bytes).
# Item: 2020-02-28_12:29.mp4 (25405141 bytes).
# Item: 2020-02-28_13:04.mp4 (27515544 bytes).
# Item: 2020-02-28_13:20.mp4 (25743342 bytes).
# Item: 2020-02-28_14:46.mp4 (25393728 bytes).
# Item: 2020-02-28_14:51.mp4 (25234346 bytes).
# Item: 2020-02-28_15:50.mp4 (25933091 bytes).
# Item: 2020-02-28_16:24.mp4 (25327037 bytes).
# Item: 2020-02-28_16:30.mp4 (27025344 bytes).
# Item: 2020-02-28_16:49.mp4 (27198376 bytes).
# Item: 2020-02-28_16:50.mp4 (26870803 bytes).
# Item: 2020-02-28_16:52.mp4 (25723109 bytes).
# Item: 2020-02-28_16:54.mp4 (26559788 bytes).
# Item: 2020-02-28_16:56.mp4 (26549176 bytes).
# Item: 2020-02-28_17:00.mp4 (26385470 bytes).
# Item: 2020-02-28_17:02.mp4 (25878675 bytes).
# Item: 2020-02-28_17:03.mp4 (24446360 bytes).
# Item: 2020-02-28_17:05.mp4 (26250080 bytes).
# Item: 2020-02-28_17:07.mp4 (26692014 bytes).
# Item: 2020-02-28_17:10.mp4 (26763499 bytes).
# Item: 2020-02-28_17:12.mp4 (26796537 bytes).
# Item: 2020-02-28_17:13.mp4 (26675561 bytes).
# Item: 2020-02-28_17:16.mp4 (27005645 bytes).
# Item: 2020-02-28_17:18.mp4 (26801711 bytes).
# Item: 2020-02-28_17:20.mp4 (26820491 bytes).
# Item: 2020-02-28_17:23.mp4 (26569340 bytes).
# Item: 2020-02-28_17:26.mp4 (26785823 bytes).
# Item: test_upload.jpg (51795 bytes).

# %%
def get_item(bucket_name, item_name):
    print("Retrieving item from bucket: {0}, key: {1}".format(bucket_name, item_name))
    try:
        file = cos.Object(bucket_name, item_name).get()
        print("File Contents: {0}".format(file["Body"].read()))
    except ClientError as be:
        print("CLIENT ERROR: {0}\n".format(be))
    except Exception as e:
        print("Unable to retrieve file contents: {0}".format(e))

# %%
item_name = "2020-02-28_08:35.mp4"

# %%
# Below cell should work if you start notebook with the following
# jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000000

# %%
test_video = get_item(bucket_name, item_name)
# Out:
# Retrieving item from bucket: cloud-object-storage-w251-ring-video, key: 2020-02-28_08:35.mp4
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import json
import getpass
from pathlib import Path

from ring_doorbell import Ring, Auth
from oauthlib.oauth2 import MissingTokenError


cache_file = Path("ring_token.cache")


def token_updated(token):
    cache_file.write_text(json.dumps(token))


def otp_callback():
    auth_code = input("2FA code: ")
    return auth_code


def ring_first_login():
    if cache_file.is_file():
        auth = Auth("MyProject/1.0", json.loads(cache_file.read_text()), token_updated)
    else:
        username = input("Username: ")
        password = getpass.getpass("Password: ")
        auth = Auth("MyProject/1.0", None, token_updated)
        try:
            auth.fetch_token(username, password)
        except MissingTokenError:
            auth.fetch_token(username, password, otp_callback())

    ring = Ring(auth)
    ring.update_data()

    devices = ring.devices()
    print(devices)

# %%
ring_first_login()
# Out:
# Username: Brandon.fennema@gmail.com
# Password: ········
# 2FA code: 298744
# {'stickup_cams': [], 'chimes': [], 'doorbots': [<RingDoorBell: Front Door>], 'authorized_doorbots': []}

# %%
# Generate a new token

auth = Auth("MyProject/1.0", json.loads(cache_file.read_text()), token_updated)
ring = Ring(auth)
ring.update_data()
devices = ring.devices()

pprint(ring.session['profile'])
# Out:
# {'account_type': None,
#  'app_brand': 'ring',
#  'authentication_token': '_3yy5WfBoexwdzQdNSDS',
#  'country': 'US',
#  'created_at': '2019-12-29T18:03:54Z',
#  'email': 'brandon.fennema@gmail.com',
#  'explorer_program_terms': None,
#  'features': {'2fa_dur_reg_enabled': False,
#               'accelerated_alarm_enabled': True,
#               'accessories_upsell_1_0_enabled': False,
#               'adaptive_video_play_enabled': True,
#               'advanced_motion_detection_device_types': ['doorbell_portal',
#                                                          'cocoa_camera',
#                                                          'cocoa_doorbell',
#                                                          'doorbell_scallop',
#                                                          'doorbell_scallop_lite'],
#               'advanced_motion_detection_human_only_mode_enabled': False,
#               'advanced_motion_zones_device_types': [],
#               'advanced_motion_zones_enabled': False,
#               'alarm_2_0_enabled': False,
#               'alarm_700_series_enabled': False,
#               'alarm_denmark_enabled': False,
#               'alarm_finland_enabled': False,
#               'alarm_first_alert_500_enabled': False,
#               'alarm_flatline_enabled': False,
#               'alarm_iceland_enabled': False,
#               'alarm_ireland_enabled': False,
#               'alarm_ivr_on_cancel': True,
#               'alarm_language_preference_enabled': False,
#               'alarm_norway_enabled': False,
#               'alarm_reminders_enabled': False,
#               'alarm_sensitive_strips_enabled': False,
#               'alarm_sweden_enabled': False,
#               'alexa_aed_enabled': True,
#               'amazon_account_linking_enabled': True,
#               'amazon_key_setup': True,
#               'amazon_key_tile_unlock': True,
#               'ambient_light_sensor_dpd_enabled': False,
#               'ambient_light_sensor_lpd_enabled': False,
#               'answer_prestreaming_enabled': False,
#               'app_alert_tones_enabled': True,
#               'audio_recording': True,
#               'audio_recording_toggle_enabled': True,
#               'avp_slq_enabled': False,
#               'bar_enabled': False,
#               'battery_hw_h264_decoder_enabled': True,
#               'beams_custom_sensitivity_enabled': True,
#               'bypass_account_verification': False,
#               'camera_groups_enabled': False,
#               'ch_auto_detection_enabled': False,
#               'chime_dnd_enabled': False,
#               'chime_pro_bt_setup_enabled': True,
#               'chime_pro_enabled': True,
#               'chime_v2_enabled': False,
#               'cocoa_camera_enabled': True,
#               'cocoa_doorbell_enabled': False,
#               'cocoa_ignore_zones_enabled': True,
#               'cocoa_motion_battery_optimization_enabled': False,
#               'cocoa_pwr_mds_enabled': False,
#               'color_night_mode_lpd_all': True,
#               'con_cen_enabled': True,
#               'connectivity_wizard_enabled': True,
#               'control_external_lights_enabled': False,
#               'dashboard_control': False,
#               'dashboard_help_tile_enabled': True,
#               'default_snapshot_tile_dashboard_enabled': True,
#               'delete_all_enabled': True,
#               'delete_all_settings_enabled': False,
#               'detailed_offline_messaging_enabled': False,
#               'device_auth_magic_setup_enabled': True,
#               'device_controls_menu_enabled': False,
#               'device_health_alerts_enabled': True,
#               'device_settings_v2_enabled': True,
#               'dispatch_monitoring_v2_enabled': True,
#               'doorbell_portal_enabled': True,
#               'doorbell_scallop_enabled': False,
#               'doorbell_v2_enabled': True,
#               'duress_alarm_enabled': True,
#               'duress_alarm_test_enabled': True,
#               'elite_cam_enabled': True,
#               'email_verification_enabled': True,
#               'fast_app_start_caching_disabled': False,
#               'ff_24x7_lite_enabled': True,
#               'ff_24x7_lite_frequency_switch': True,
#               'ff_offline_motion_events_enabled': False,
#               'floodlight_cam_enabled': True,
#               'fullscreen_scanning_enabled': False,
#               'gelato_enabled': False,
#               'global_snooze_enabled': True,
#               'group_sharing_enabled': False,
#               'group_sharing_v2_enabled': False,
#               'group_sharing_v3_enabled': False,
#               'guest_user_scheduling_enabled': True,
#               'hdr_enabled_dpdv4': True,
#               'hdr_enabled_lunar': False,
#               'high_contrast_mode': False,
#               'history_updates_daterange_enabled': False,
#               'in_app_call_notifications': True,
#               'in_app_chat_enabled': False,
#               'invite_program_without_credit': True,
#               'key_delivery_clip_filter_enabled': True,
#               'keypad_chirps_enabled': True,
#               'knock_alerts_enabled': False,
#               'landscape_view_device_controls_menu_enabled': False,
#               'legacy_cvr_retention_enabled': False,
#               'leo_device_setup_unlock_enabled': True,
#               'light_groups_enabled': False,
#               'light_schedule_wizard_enabled': False,
#               'linked_devices_beams_tile_enabled': False,
#               'linked_devices_enabled': True,
#               'linked_devices_modes_enabled': False,
#               'linked_devices_ring_tile_enabled': False,
#               'linked_devices_setup_enabled': True,
#               'linked_devices_tile_enabled': True,
#               'live_quality_indicators_enabled': False,
#               'live_view_settings_enabled': True,
#               'loitering_detection_device_types': [],
#               'lpd_enabled': True,
#               'lpd_motion_announcement_enabled': False,
#               'mac_no_device_settings_enabled': False,
#               'manual_exposure_enabled': False,
#               'min_max_enabled_dpd_lunar': False,
#               'min_max_enabled_dpd_nonv4': False,
#               'min_max_enabled_dpd_v4': False,
#               'motion_detection_toggle_enabled': False,
#               'motion_snoozing_enabled': True,
#               'motion_zones_v2_enabled': False,
#               'mp_enabled': False,
#               'multiple_calls_enabled': True,
#               'multiple_delete_enabled': True,
#               'name_peephole_toggle_enabled': False,
#               'native_lock_unlock': True,
#               'new_features_2_0_enabled': True,
#               'new_timeline_layout': False,
#               'nh_case_information_enabled': False,
#               'nh_case_resolution_enabled': False,
#               'nh_referral_v2_enabled': False,
#               'nh_referral_v2_ring_core_enabled': False,
#               'night_mode_lunar': False,
#               'night_mode_orion': False,
#               'non_dispatch_monitoring_enabled': True,
#               'non_owner_setup_check_enabled': True,
#               'nw_case_resolve_enabled': False,
#               'nw_crime_recap_share_enabled': True,
#               'nw_enabled': True,
#               'nw_feed_types_enabled': True,
#               'nw_larger_area_enabled': False,
#               'nw_map_view_feature_enabled': True,
#               'nw_notification_radius_enabled': True,
#               'nw_notification_types_enabled': True,
#               'nw_reply_to_comments_enabled': True,
#               'nw_user_activated': False,
#               'nw_v2_enabled': True,
#               'object_bounding_box_enabled': False,
#               'onetwothreetest': True,
#               'ota_timer_enabled': True,
#               'owner_proactive_snoozing_enabled': True,
#               'people_only_mode_device_types': ['cocoa_doorbell',
#                                                 'doorbell_scallop',
#                                                 'doorbell_scallop_lite'],
#               'people_only_mode_lpd_enabled': True,
#               'pip_enabled': False,
#               'police_portal_video_requests_enabled': True,
#               'pom_recording_preferences_enabled': False,
#               'post_setup_flow_enabled': False,
#               'power_cable_enabled': False,
#               'privacy_settings': True,
#               'privacy_zones_device_types': [],
#               'proactive_snoozing_enabled': False,
#               'raw_video_enabled': True,
#               'reactive_snoozing_enabled': False,
#               'record_motion_enabled': False,
#               'recording_indicators_device_type_enabled': [],
#               'remote_logging_format_storing': False,
#               'remote_logging_level': 1,
#               'review_prompt_enabled': True,
#               'rich_notifications_enabled': False,
#               'ring_alarm_enabled': True,
#               'ring_beams_enabled': True,
#               'ring_beams_transformer_enabled': True,
#               'ring_beams_wired_light_schedule_controls': True,
#               'ring_cam_battery_enabled': True,
#               'ring_cam_enabled': True,
#               'ring_cam_mount_enabled': True,
#               'ring_cash_eligible_enabled': False,
#               'ring_doorbox_enabled': False,
#               'ring_for_business_enabled': True,
#               'ring_for_business_prompt_enabled': True,
#               'ring_search_enabled': False,
#               'ringplus_enabled': True,
#               'rn_opt_in_enabled': False,
#               'rotate_180_deg_enabled': True,
#               'rpp_subscriptions_enabled': True,
#               'rs.devicecatalog.whitelist.device.gen2devices': False,
#               'scallop_pre_roll_enabled': False,
#               'scrubber_auto_live_enabled': True,
#               'scrubber_enabled': True,
#               'setup_shared_users_tutorial_v2_enabled': False,
#               'show_red_tails_toggle': False,
#               'sidewalk_feature_enabled': False,
#               'silence_alarm_siren_enabled': True,
#               'snapshot_tile_dashboard_enabled': True,
#               'sos_medical_enabled': True,
#               'sound_alarm_siren_enabled': True,
#               'spotlight_battery_dashboard_controls_enabled': False,
#               'spotlight_scheduling_enabled': False,
#               'srtp_enabled': True,
#               'starred_events_enabled': True,
#               'state_of_the_home_enabled': False,
#               'stickup_cam_mini_enabled': True,
#               'stickupcam_battery_setup_enabled': False,
#               'stickupcam_elite_setup_enabled': False,
#               'stickupcam_setup_enabled': True,
#               'streaming_data_in_pn_enabled': False,
#               'subs_attachment_enabled': False,
#               'subscriptions_enabled': True,
#               'swk_ct_enabled': False,
#               'sync_vod_dpd_enabled': False,
#               'sync_vod_lpd_enabled': True,
#               'test': 0,
#               'tile_dashboard_enabled': False,
#               'tile_dashboard_mode': 'snapshot',
#               'timeline_adopt_p1_enabled': False,
#               'timeline_adopt_p2_enabled': False,
#               'timeline_adoption_endgame_enabled': False,
#               'timeline_default_enabled': False,
#               'timeline_force_enabled': True,
#               'timeline_thumbnails_enabled': True,
#               'twenty_four_seven_lite_enabled': False,
#               'two_factor_auth_enabled': True,
#               'ujet_enabled': True,
#               'unverified_address_V2_enabled': True,
#               'vf_tr_a': False,
#               'vf_tr_b': False,
#               'video_feedback_enabled': False,
#               'video_request_enabled': False,
#               'video_resolutions_dpd_enabled': False,
#               'video_resolutions_lpd_enabled': False,
#               'video_search_enabled': False,
#               'vod_enabled': False,
#               'vrl_cocoa_enabled': False,
#               'vrl_dpd_enabled': False,
#               'webrtc_enabled': False,
#               'websockets_enabled': False,
#               'wired_hw_h264_decoder_enabled': False,
#               'x_line_enabled': False},
#  'first_name': 'Brandon',
#  'hardware_id': 'c5bfdfab0f08406b92550863e3f45379',
#  'id': 24455228,
#  'last_name': 'Fennema',
#  'phone_number': '18582323070',
#  'status': 'verified',
#  'tfa_enabled': True,
#  'tfa_phone_number': '+18582323070',
#  'user_flow': 'ring',
#  'user_preferences': {'preferences': {}, 'settings': {}}}

# %%
devices = ring.devices()
doorbell = devices['doorbots'][0]
doorbell.recording_download(
    doorbell.history(limit=100, kind='ding')[0]['id'],
                     filename='last_ding.mp4',
                     override=True)
# Out:
# True

# %%
devices = ring.devices()
for doorbell in devices['doorbots']:

    # listing the last 15 events of any kind
    for event in doorbell.history(limit=15):
        print('ID:       %s' % event['id'])
        print('Kind:     %s' % event['kind'])
        print('Answered: %s' % event['answered'])
        print('When:     %s' % event['created_at'])
        print('--' * 50)
# Out:
# ID:       6798673830757708585
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:26:44+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798672920224641833
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:23:12+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798672331814122281
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:20:55+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798671670389158697
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:18:21+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798671154993083177
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:16:21+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798670338949296937
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:13:11+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798670038301586217
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:12:01+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798669694704202537
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:10:41+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798668878660416297
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:07:31+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798668449163686697
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:05:51+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798667877933036329
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:03:38+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798667598760162089
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:02:33+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798666963105002281
# Kind:     motion
# Answered: False
# When:     2020-02-29 01:00:05+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798665988147426089
# Kind:     motion
# Answered: False
# When:     2020-02-29 00:56:18+00:00
# ----------------------------------------------------------------------------------------------------
# ID:       6798665601600369449
# Kind:     motion
# Answered: False
# When:     2020-02-29 00:54:48+00:00
# ----------------------------------------------------------------------------------------------------

# %%
from ring_doorbell import Ring
import urllib.request
from datetime import datetime, timedelta, date
import pytz
import configparser
import logging
import os

pst = pytz.timezone('US/Pacific')

# %%
print(video_history)
# Out:
# [{'id': 6798673830757708585, 'created_at': datetime.datetime(2020, 2, 29, 1, 26, 44, tzinfo=<UTC>), 'answered': False, 'events': [], 'kind': 'motion', 'favorite': False, 'snapshot_url': '', 'recording': {'status': 'ready'}, 'duration': 61.0, 'cv_properties': {'person_detected': None, 'stream_broken': None, 'detection_type': None}}, {'id': 6798672920224641833, 'created_at': datetime.datetime(2020, 2, 29, 1, 23, 12, tzinfo=<UTC>), 'answered': False, 'events': [], 'kind': 'motion', 'favorite': False, 'snapshot_url': '', 'recording': {'status': 'ready'}, 'duration': 61.0, 'cv_properties': {'person_detected': None, 'stream_broken': None, 'detection_type': None}}]

# %%
# bucket_name = "cloud-object-storage-w251-ring-video"
# upload_filename = "/Users/katayounborojerdi/Desktop/IMG_3521.jpg"
# object_name = "test_upload.jpg"

video_history = doorbell.history(limit = 30)
for video in video_history:
    print(video['id'])
    filename = video['created_at'].astimezone(pst).strftime("%Y-%m-%d_%H:%M") + ".mp4"
    upload_filename = "/Users/katayounborojerdi/" + filename
    print(filename)

    doorbell.recording_download(video['id'],filename,override=True)
    
    upload_large_file(bucket_name, filename, upload_filename)
    
    os.remove(filename)
# Out:
# 6798673830757708585
# 2020-02-28_17:26.mp4
# Starting large file upload for 2020-02-28_17:26.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798672920224641833
# 2020-02-28_17:23.mp4
# Starting large file upload for 2020-02-28_17:23.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798672331814122281
# 2020-02-28_17:20.mp4
# Starting large file upload for 2020-02-28_17:20.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798671670389158697
# 2020-02-28_17:18.mp4
# Starting large file upload for 2020-02-28_17:18.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798671154993083177
# 2020-02-28_17:16.mp4
# Starting large file upload for 2020-02-28_17:16.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798670338949296937
# 2020-02-28_17:13.mp4
# Starting large file upload for 2020-02-28_17:13.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798670038301586217
# 2020-02-28_17:12.mp4
# Starting large file upload for 2020-02-28_17:12.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798669694704202537
# 2020-02-28_17:10.mp4
# Starting large file upload for 2020-02-28_17:10.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798668878660416297
# 2020-02-28_17:07.mp4
# Starting large file upload for 2020-02-28_17:07.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798668449163686697
# 2020-02-28_17:05.mp4
# Starting large file upload for 2020-02-28_17:05.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798667877933036329
# 2020-02-28_17:03.mp4
# Starting large file upload for 2020-02-28_17:03.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798667598760162089
# 2020-02-28_17:02.mp4
# Starting large file upload for 2020-02-28_17:02.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798666963105002281
# 2020-02-28_17:00.mp4
# Starting large file upload for 2020-02-28_17:00.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798665988147426089
# 2020-02-28_16:56.mp4
# Starting large file upload for 2020-02-28_16:56.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798665601600369449
# 2020-02-28_16:54.mp4
# Starting large file upload for 2020-02-28_16:54.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798665051844555561
# 2020-02-28_16:52.mp4
# Starting large file upload for 2020-02-28_16:52.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798664613757891369
# 2020-02-28_16:50.mp4
# Starting large file upload for 2020-02-28_16:50.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798664274455474985
# 2020-02-28_16:49.mp4
# Starting large file upload for 2020-02-28_16:49.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798659305178313513
# 2020-02-28_16:30.mp4
# Starting large file upload for 2020-02-28_16:30.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798657896429040425
# 2020-02-28_16:24.mp4
# Starting large file upload for 2020-02-28_16:24.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798648902767522601
# 2020-02-28_15:50.mp4
# Starting large file upload for 2020-02-28_15:50.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798633737238000425
# 2020-02-28_14:51.mp4
# Starting large file upload for 2020-02-28_14:51.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798632483107549993
# 2020-02-28_14:46.mp4
# Starting large file upload for 2020-02-28_14:46.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798610273831662377
# 2020-02-28_13:20.mp4
# Starting large file upload for 2020-02-28_13:20.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798606275217109801
# 2020-02-28_13:04.mp4
# Starting large file upload for 2020-02-28_13:04.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798597264375722793
# 2020-02-28_12:29.mp4
# Starting large file upload for 2020-02-28_12:29.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798595499144164137
# 2020-02-28_12:22.mp4
# Starting large file upload for 2020-02-28_12:22.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798586681576305449
# 2020-02-28_11:48.mp4
# Starting large file upload for 2020-02-28_11:48.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798586376633627433
# 2020-02-28_11:47.mp4
# Starting large file upload for 2020-02-28_11:47.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
# 6798536967329854249
# 2020-02-28_08:35.mp4
# Starting large file upload for 2020-02-28_08:35.mp4 to bucket: cloud-object-storage-w251-ring-video
# Large file upload complete!
